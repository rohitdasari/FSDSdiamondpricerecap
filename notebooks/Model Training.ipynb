# %% [markdown]
# ## Model training

# %%
import pandas as pd

# %%
df = pd.read_csv('data/gemstone.csv')

# %%
df
# Out:
#             id  carat        cut color clarity  depth  table     x     y  \
# 0            0   1.52    Premium     F     VS2   62.2   58.0  7.27  7.33
# 1            1   2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12
# 2            2   0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73
# 3            3   0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41
# 4            4   1.70    Premium     G     VS2   62.6   59.0  7.65  7.61
# ...        ...    ...        ...   ...     ...    ...    ...   ...   ...
# 193568  193568   0.31      Ideal     D    VVS2   61.1   56.0  4.35  4.39
# 193569  193569   0.70    Premium     G    VVS2   60.3   58.0  5.75  5.77
# 193570  193570   0.73  Very Good     F     SI1   63.1   57.0  5.72  5.75
# 193571  193571   0.34  Very Good     D     SI1   62.9   55.0  4.45  4.49
# 193572  193572   0.71       Good     E     SI2   60.8   64.0  5.73  5.71
#
#            z  price
# 0       4.55  13619
# 1       5.05  13387
# 2       3.50   2772
# 3       2.71    666
# 4       4.77  14453
# ...      ...    ...
# 193568  2.67   1130
# 193569  3.47   2874
# 193570  3.62   3036
# 193571  2.81    681
# 193572  3.48   2258
#
# [193573 rows x 11 columns]

# %%
df.head()
# Out:
#    id  carat        cut color clarity  depth  table     x     y     z  price
# 0   0   1.52    Premium     F     VS2   62.2   58.0  7.27  7.33  4.55  13619
# 1   1   2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12  5.05  13387
# 2   2   0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73  3.50   2772
# 3   3   0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41  2.71    666
# 4   4   1.70    Premium     G     VS2   62.6   59.0  7.65  7.61  4.77  14453

# %%
df.drop(labels='id',axis = 1)
# Out:
#         carat        cut color clarity  depth  table     x     y     z  price
# 0        1.52    Premium     F     VS2   62.2   58.0  7.27  7.33  4.55  13619
# 1        2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12  5.05  13387
# 2        0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73  3.50   2772
# 3        0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41  2.71    666
# 4        1.70    Premium     G     VS2   62.6   59.0  7.65  7.61  4.77  14453
# ...       ...        ...   ...     ...    ...    ...   ...   ...   ...    ...
# 193568   0.31      Ideal     D    VVS2   61.1   56.0  4.35  4.39  2.67   1130
# 193569   0.70    Premium     G    VVS2   60.3   58.0  5.75  5.77  3.47   2874
# 193570   0.73  Very Good     F     SI1   63.1   57.0  5.72  5.75  3.62   3036
# 193571   0.34  Very Good     D     SI1   62.9   55.0  4.45  4.49  2.81    681
# 193572   0.71       Good     E     SI2   60.8   64.0  5.73  5.71  3.48   2258
#
# [193573 rows x 10 columns]

# %%
df = df.drop(labels='id',axis = 1)

# %%
df.head()
# Out:
#    carat        cut color clarity  depth  table     x     y     z  price
# 0   1.52    Premium     F     VS2   62.2   58.0  7.27  7.33  4.55  13619
# 1   2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12  5.05  13387
# 2   0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73  3.50   2772
# 3   0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41  2.71    666
# 4   1.70    Premium     G     VS2   62.6   59.0  7.65  7.61  4.77  14453

# %%
## Independent and dependent features

X = df.drop(labels='price',axis = 1)
Y = df[['price']]

# %%
df.head()
# Out:
#    carat        cut color clarity  depth  table     x     y     z  price
# 0   1.52    Premium     F     VS2   62.2   58.0  7.27  7.33  4.55  13619
# 1   2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12  5.05  13387
# 2   0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73  3.50   2772
# 3   0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41  2.71    666
# 4   1.70    Premium     G     VS2   62.6   59.0  7.65  7.61  4.77  14453

# %%
df.columns
# Out:
# Index(['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'x', 'y', 'z',
#        'price'],
#       dtype='object')

# %%
X
# Out:
#         carat        cut color clarity  depth  table     x     y     z
# 0        1.52    Premium     F     VS2   62.2   58.0  7.27  7.33  4.55
# 1        2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12  5.05
# 2        0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73  3.50
# 3        0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41  2.71
# 4        1.70    Premium     G     VS2   62.6   59.0  7.65  7.61  4.77
# ...       ...        ...   ...     ...    ...    ...   ...   ...   ...
# 193568   0.31      Ideal     D    VVS2   61.1   56.0  4.35  4.39  2.67
# 193569   0.70    Premium     G    VVS2   60.3   58.0  5.75  5.77  3.47
# 193570   0.73  Very Good     F     SI1   63.1   57.0  5.72  5.75  3.62
# 193571   0.34  Very Good     D     SI1   62.9   55.0  4.45  4.49  2.81
# 193572   0.71       Good     E     SI2   60.8   64.0  5.73  5.71  3.48
#
# [193573 rows x 9 columns]

# %%
Y
# Out:
#         price
# 0       13619
# 1       13387
# 2        2772
# 3         666
# 4       14453
# ...       ...
# 193568   1130
# 193569   2874
# 193570   3036
# 193571    681
# 193572   2258
#
# [193573 rows x 1 columns]

# %%
X.select_dtypes(include = 'object').columns
# Out:
# Index(['cut', 'color', 'clarity'], dtype='object')

# %%
X.select_dtypes(exclude='object').columns
# Out:
# Index(['carat', 'depth', 'table', 'x', 'y', 'z'], dtype='object')

# %%
X.columns[X.dtypes!='object']
# Out:
# Index(['carat', 'depth', 'table', 'x', 'y', 'z'], dtype='object')

# %%
X.dtypes!='object'
# Out:
# carat       True
# cut        False
# color      False
# clarity    False
# depth       True
# table       True
# x           True
# y           True
# z           True
# dtype: bool

# %%
X.columns[X.dtypes!='object']
# Out:
# Index(['carat', 'depth', 'table', 'x', 'y', 'z'], dtype='object')

# %%
X.columns[X.dtypes=='object']
# Out:
# Index(['cut', 'color', 'clarity'], dtype='object')

# %%
X.select_dtypes(include='object').columns
# Out:
# Index(['cut', 'color', 'clarity'], dtype='object')

# %%
categorical_cols = X.select_dtypes(include = 'object').columns
numerical_cols = X.select_dtypes(exclude='object').columns

# %%
categorical_cols
# Out:
# Index(['cut', 'color', 'clarity'], dtype='object')

# %%
numerical_cols
# Out:
# Index(['carat', 'depth', 'table', 'x', 'y', 'z'], dtype='object')

# %%
df['cut'].unique()
# Out:
# array(['Premium', 'Very Good', 'Ideal', 'Good', 'Fair'], dtype=object)

# %%
df['clarity'].unique()
# Out:
# array(['VS2', 'SI2', 'VS1', 'SI1', 'IF', 'VVS2', 'VVS1', 'I1'],
#       dtype=object)

# %%
df['color'].unique()
# Out:
# array(['F', 'J', 'G', 'E', 'D', 'H', 'I'], dtype=object)

# %%
cut_categories = ['Fair','Good','Very Good','Premium','Ideal']
color_categories = ['D','E','F','G','H', 'I','J']
clarity_categories = ['I1','SI2','SI1','VS2','VS1','VVS2', 'VVS1','IF']

# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /Users/rohitdasari/learning/ineuron/projects-ML/diamondprice_recap/venv/lib/python3.8/site-packages (1.3.2)
# Requirement already satisfied: numpy<2.0,>=1.17.3 in /Users/rohitdasari/learning/ineuron/projects-ML/diamondprice_recap/venv/lib/python3.8/site-packages (from scikit-learn) (1.24.4)
# Requirement already satisfied: scipy>=1.5.0 in /Users/rohitdasari/learning/ineuron/projects-ML/diamondprice_recap/venv/lib/python3.8/site-packages (from scikit-learn) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in /Users/rohitdasari/learning/ineuron/projects-ML/diamondprice_recap/venv/lib/python3.8/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/rohitdasari/learning/ineuron/projects-ML/diamondprice_recap/venv/lib/python3.8/site-packages (from scikit-learn) (3.5.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.impute import SimpleImputer   ##handling missing values
from sklearn.preprocessing import StandardScaler   ##handling feature scaling
from sklearn.preprocessing import OrdinalEncoder    ##ordinal encoding

## pipelines

from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

# %%
## numerical pipeline

num_pipeline = Pipeline(
    steps=[
        ('imputer',SimpleImputer(strategy='median')),
        ('scaler',StandardScaler())

        ]
)



## categorical pipeline 


cat_pipeline = Pipeline(
    steps=[
        ('imputer',SimpleImputer(strategy='most_frequent')),
        ('ordinal encedor',OrdinalEncoder(categories=[cut_categories,color_categories,clarity_categories])),
        ('scaler',StandardScaler())
    ]
)


preprocessor = ColumnTransformer([
    ('num_pipeline',num_pipeline,numerical_cols),
    ('cat_pipeline',cat_pipeline,categorical_cols)
])

# %%
preprocessor
# Out:
# ColumnTransformer(transformers=[('num_pipeline',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('scaler', StandardScaler())]),
#                                  Index(['carat', 'depth', 'table', 'x', 'y', 'z'], dtype='object')),
#                                 ('cat_pipeline',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('ordinal encedor',
#                                                   OrdinalEncoder(categories=[['Fair',
#                                                                               'Good',
#                                                                               'Very '
#                                                                               'Good',
#                                                                               'Premium',
#                                                                               'Ideal'],
#                                                                              ['D',
#                                                                               'E',
#                                                                               'F',
#                                                                               'G',
#                                                                               'H',
#                                                                               'I',
#                                                                               'J'],
#                                                                              ['I1',
#                                                                               'SI2',
#                                                                               'SI1',
#                                                                               'VS2',
#                                                                               'VS1',
#                                                                               'VVS2',
#                                                                               'VVS1',
#                                                                               'IF']])),
#                                                  ('scaler', StandardScaler())]),
#                                  Index(['cut', 'color', 'clarity'], dtype='object'))])

# %%
df[numerical_cols]
# Out:
#         carat  depth  table     x     y     z
# 0        1.52   62.2   58.0  7.27  7.33  4.55
# 1        2.03   62.0   58.0  8.06  8.12  5.05
# 2        0.70   61.2   57.0  5.69  5.73  3.50
# 3        0.32   61.6   56.0  4.38  4.41  2.71
# 4        1.70   62.6   59.0  7.65  7.61  4.77
# ...       ...    ...    ...   ...   ...   ...
# 193568   0.31   61.1   56.0  4.35  4.39  2.67
# 193569   0.70   60.3   58.0  5.75  5.77  3.47
# 193570   0.73   63.1   57.0  5.72  5.75  3.62
# 193571   0.34   62.9   55.0  4.45  4.49  2.81
# 193572   0.71   60.8   64.0  5.73  5.71  3.48
#
# [193573 rows x 6 columns]

# %%
df[categorical_cols]
# Out:
#               cut color clarity
# 0         Premium     F     VS2
# 1       Very Good     J     SI2
# 2           Ideal     G     VS1
# 3           Ideal     G     VS1
# 4         Premium     G     VS2
# ...           ...   ...     ...
# 193568      Ideal     D    VVS2
# 193569    Premium     G    VVS2
# 193570  Very Good     F     SI1
# 193571  Very Good     D     SI1
# 193572       Good     E     SI2
#
# [193573 rows x 3 columns]

# %%
cat_pipeline
# Out:
# Pipeline(steps=[('imputer', SimpleImputer(strategy='most_frequent')),
#                 ('ordinal encedor',
#                  OrdinalEncoder(categories=[['Fair', 'Good', 'Very Good',
#                                              'Premium', 'Ideal'],
#                                             ['D', 'E', 'F', 'G', 'H', 'I', 'J'],
#                                             ['I1', 'SI2', 'SI1', 'VS2', 'VS1',
#                                              'VVS2', 'VVS1', 'IF']])),
#                 ('scaler', StandardScaler())])

# %%
## train test split

from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,Y,test_size=0.30,random_state=42)

# %%
X_train
# Out:
#         carat        cut color clarity  depth  table     x     y     z
# 11504    0.41      Ideal     E    VVS2   60.6   56.0  4.85  4.80  2.93
# 95284    1.23  Very Good     H     VS1   59.9   59.0  6.91  7.01  4.19
# 184777   1.70    Premium     H     VS2   62.0   58.0  7.61  7.66  4.74
# 5419     0.33      Ideal     F    VVS1   61.2   56.0  4.47  4.44  2.73
# 45466    0.33  Very Good     I     SI1   62.1   58.0  4.41  4.45  2.75
# ...       ...        ...   ...     ...    ...    ...   ...   ...   ...
# 119879   0.50  Very Good     E     SI1   60.2   61.0  5.11  5.15  3.09
# 103694   1.91  Very Good     F     SI1   62.3   62.0  7.85  7.79  4.87
# 131932   1.22    Premium     G     VS2   62.8   58.0  6.82  6.74  4.26
# 146867   0.31  Very Good     G    VVS1   61.1   56.0  4.37  4.40  2.67
# 121958   0.31  Very Good     G     SI2   61.8   59.0  4.34  4.38  2.70
#
# [135501 rows x 9 columns]

# %%
X_test
# Out:
#         carat        cut color clarity  depth  table     x     y     z
# 14868    0.50      Ideal     D     SI1   62.1   57.0  5.05  5.08  3.14
# 165613   2.00  Very Good     G     SI2   59.5   57.0  8.08  8.15  4.89
# 96727    0.27    Premium     E    VVS1   60.5   59.0  4.19  4.16  2.52
# 145593   0.32    Premium     I    VVS1   61.2   59.0  4.43  4.44  2.71
# 118689   1.19      Ideal     H     SI1   62.5   56.0  6.77  6.81  4.23
# ...       ...        ...   ...     ...    ...    ...   ...   ...   ...
# 39151    0.91  Very Good     I     SI2   62.4   59.0  6.18  6.13  3.83
# 32423    0.51      Ideal     D     VS2   62.4   56.0  5.13  5.11  3.19
# 17876    0.41      Ideal     G    VVS1   61.8   56.0  4.79  4.77  2.95
# 72938    1.21    Premium     I     SI1   61.1   60.0  6.88  6.79  4.18
# 2265     1.01  Very Good     E     VS2   62.8   56.0  6.33  6.46  4.02
#
# [58072 rows x 9 columns]

# %%
y_train
# Out:
#         price
# 11504    1181
# 95284    7418
# 184777  12755
# 5419     1020
# 45466     445
# ...       ...
# 119879   1410
# 103694  15064
# 131932   7209
# 146867    816
# 121958    408
#
# [135501 rows x 1 columns]

# %%
y_test
# Out:
#         price
# 14868    1355
# 165613  14691
# 96727     844
# 145593    707
# 118689   5797
# ...       ...
# 39151    2974
# 32423    1875
# 17876     967
# 72938    5656
# 2265     6759
#
# [58072 rows x 1 columns]

# %%
X_train = pd.DataFrame(preprocessor.fit_transform(X_train),columns = preprocessor.get_feature_names_out())
X_test = pd.DataFrame(preprocessor.transform(X_test),columns=preprocessor.get_feature_names_out())

# %%
X_train
# Out:
#         num_pipeline__carat  num_pipeline__depth  num_pipeline__table  \
# 0                 -0.823144            -1.129988            -0.641897
# 1                  0.945023            -1.777823             0.921902
# 2                  1.958484             0.165682             0.400636
# 3                 -0.995648            -0.574701            -0.641897
# 4                 -0.995648             0.258230             0.400636
# ...                     ...                  ...                  ...
# 135496            -0.629077            -1.500179             1.964434
# 135497             2.411307             0.443325             2.485700
# 135498             0.923460             0.906065             0.400636
# 135499            -1.038774            -0.667249            -0.641897
# 135500            -1.038774            -0.019414             0.921902
#
#         num_pipeline__x  num_pipeline__y  num_pipeline__z  cat_pipeline__cut  \
# 0             -0.780451        -0.835103        -0.876024           0.874100
# 1              1.073226         1.166389         0.946633          -1.137644
# 2              1.703116         1.755063         1.742237          -0.131772
# 3             -1.122391        -1.161138        -1.165334           0.874100
# 4             -1.176382        -1.152082        -1.136403          -1.137644
# ...                 ...              ...              ...                ...
# 135496        -0.546492        -0.518125        -0.644575          -1.137644
# 135497         1.919078         1.872797         1.930288          -1.137644
# 135498         0.992240         0.921862         1.047891          -0.131772
# 135499        -1.212375        -1.197364        -1.252127          -1.137644
# 135500        -1.239371        -1.215477        -1.208731          -1.137644
#
#         cat_pipeline__color  cat_pipeline__clarity
# 0                 -0.936747               1.350746
# 1                  0.910853               0.684455
# 2                  0.910853               0.018164
# 3                 -0.320880               2.017037
# 4                  1.526720              -0.648127
# ...                     ...                    ...
# 135496            -0.936747              -0.648127
# 135497            -0.320880              -0.648127
# 135498             0.294987               0.018164
# 135499             0.294987               2.017037
# 135500             0.294987              -1.314417
#
# [135501 rows x 9 columns]

# %%
X_test
# Out:
#        num_pipeline__carat  num_pipeline__depth  num_pipeline__table  \
# 0                -0.629077             0.258230            -0.120630
# 1                 2.605374            -2.148014            -0.120630
# 2                -1.125026            -1.222536             0.921902
# 3                -1.017211            -0.574701             0.921902
# 4                 0.858771             0.628421            -0.641897
# ...                    ...                  ...                  ...
# 58067             0.255007             0.535873             0.921902
# 58068            -0.607514             0.535873            -0.641897
# 58069            -0.823144            -0.019414            -0.641897
# 58070             0.901897            -0.667249             1.443168
# 58071             0.470637             0.906065            -0.641897
#
#        num_pipeline__x  num_pipeline__y  num_pipeline__z  cat_pipeline__cut  \
# 0            -0.600482        -0.581521        -0.572248           0.874100
# 1             2.126042         2.198832         1.959219          -1.137644
# 2            -1.374347        -1.414721        -1.469110          -0.131772
# 3            -1.158385        -1.161138        -1.194265          -0.131772
# 4             0.947248         0.985258         1.004495           0.874100
# ...                ...              ...              ...                ...
# 58067         0.416340         0.369414         0.425874          -1.137644
# 58068        -0.528495        -0.554351        -0.499920           0.874100
# 58069        -0.834441        -0.862273        -0.847093           0.874100
# 58070         1.046230         0.967145         0.932167          -0.131772
# 58071         0.551317         0.668280         0.700719          -1.137644
#
#        cat_pipeline__color  cat_pipeline__clarity
# 0                -1.552614              -0.648127
# 1                 0.294987              -1.314417
# 2                -0.936747               2.017037
# 3                 1.526720               2.017037
# 4                 0.910853              -0.648127
# ...                    ...                    ...
# 58067             1.526720              -1.314417
# 58068            -1.552614               0.018164
# 58069             0.294987               2.017037
# 58070             1.526720              -0.648127
# 58071            -0.936747               0.018164
#
# [58072 rows x 9 columns]

# %%
X_train.head()
# Out:
#    num_pipeline__carat  num_pipeline__depth  num_pipeline__table  \
# 0            -0.823144            -1.129988            -0.641897
# 1             0.945023            -1.777823             0.921902
# 2             1.958484             0.165682             0.400636
# 3            -0.995648            -0.574701            -0.641897
# 4            -0.995648             0.258230             0.400636
#
#    num_pipeline__x  num_pipeline__y  num_pipeline__z  cat_pipeline__cut  \
# 0        -0.780451        -0.835103        -0.876024           0.874100
# 1         1.073226         1.166389         0.946633          -1.137644
# 2         1.703116         1.755063         1.742237          -0.131772
# 3        -1.122391        -1.161138        -1.165334           0.874100
# 4        -1.176382        -1.152082        -1.136403          -1.137644
#
#    cat_pipeline__color  cat_pipeline__clarity
# 0            -0.936747               1.350746
# 1             0.910853               0.684455
# 2             0.910853               0.018164
# 3            -0.320880               2.017037
# 4             1.526720              -0.648127

# %%
from sklearn.linear_model import LinearRegression, Lasso, Ridge, ElasticNet
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# %%
regression = LinearRegression()
regression.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
regression.coef_
# Out:
# array([[ 6432.97591819,  -132.34206204,   -70.48787525, -1701.38593925,
#          -494.17005097,   -76.32351645,    68.80035873,  -464.67990411,
#           652.10059539]])

# %%
regression.intercept_
# Out:
# array([3976.8787389])

# %%
import numpy as np
def evaluate_model(true, predicted):
    mae = mean_absolute_error(true, predicted)
    mse = mean_squared_error(true, predicted)
    rmse = np.sqrt(mean_squared_error(true, predicted))
    r2_square = r2_score(true,predicted)
    return mae,mse,rmse,r2_square

# %%
## train multiple models 

models = {
    'LinearRegression':LinearRegression(),
    'Lasso':Lasso(),
    'Ridge':Ridge(),
    'Elasticnet':ElasticNet()
}

model_list = []
r2_list = []

for i in range(len(list(models))):
    model = list(models.values())[i]
    model.fit(X_train,y_train)


    # make predictions 

    y_pred = model.predict(X_test)

    mae,mse,rmse,r2_square = evaluate_model(y_test,y_pred)

    print(list(models.keys())[i])
    model_list.append(list(models.keys())[i])
    

    print('Model training performance')
    print('RMSE:',rmse)
    print('MAE:',mae)
    print('R2_square:',r2_square*100)

    r2_list.append(r2_square)

    print('='*35)
    print('\n')
# Out:
# LinearRegression
# Model training performance
# RMSE: 1014.6296630375489
# MAE: 675.0758270067433
# R2_square: 93.62906819996044
# ===================================
#
#
# Lasso
# Model training performance
# RMSE: 1014.6591302750638
# MAE: 676.2421173665508
# R2_square: 93.62869814082755
# ===================================
#
#
# Ridge
# Model training performance
# RMSE: 1014.6343233534446
# MAE: 675.1077629781266
# R2_square: 93.62900967491628
# ===================================
#
#
# Elasticnet
# Model training performance
# RMSE: 1533.3541245902313
# MAE: 1060.9432977143006
# R2_square: 85.44967219374031
# ===================================

# %%
r2_list
# Out:
# [0.9362906819996044,
#  0.9362869814082755,
#  0.9362900967491627,
#  0.8544967219374031]

# %%
model_list
# Out:
# ['LinearRegression', 'Lasso', 'Ridge', 'Elasticnet']
